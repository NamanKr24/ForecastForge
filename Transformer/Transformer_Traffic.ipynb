# %%
import os
import json
import math
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import torch
import random
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset
import optuna

# %%
def set_seeds(seed=42):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel("../datasets/traffic.xlsx")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df["DateTime"] = pd.to_datetime(df["DateTime"])
df.set_index("DateTime", inplace=True)
df = df[["Vehicles"]]
df = df.iloc[-3000:]

train_size = int(len(df) * 0.8)
df_train_raw = df.iloc[:train_size]
df_test_raw = df.iloc[train_size:]

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(df_train_raw)
scaled_test = scaler.transform(df_test_raw)

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(scaled_train)
X_test, y_test = create_sequences(scaled_test)

X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(-1)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(-1)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(-1)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(-1)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x

# %%
class TransformerTimeSeries(nn.Module):
    def __init__(self, feature_size=1, d_model=64, nhead=2, num_layers=1, dropout=0.1):
        super().__init__()
        self.input_linear = nn.Linear(feature_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers=num_layers)
        self.decoder = nn.Linear(d_model, 1)

    def forward(self, src):
        x = self.input_linear(src)
        x = self.pos_encoder(x)
        x = self.transformer_encoder(x)
        out = self.decoder(x[:, -1, :])
        return out

device = torch.device("cpu")

# %%
def evaluate(model, loader, scaler):
    model.eval()
    preds = []
    actuals = []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            pred = model(xb).cpu().numpy()
            preds.append(pred)
            actuals.append(yb.numpy())
    preds = np.vstack(preds)
    actuals = np.vstack(actuals)
    preds_inv = scaler.inverse_transform(preds)
    actuals_inv = scaler.inverse_transform(actuals)
    rmse = math.sqrt(mean_squared_error(actuals_inv, preds_inv))
    return preds_inv, actuals_inv, rmse

# %%
def objective(trial):
    set_seeds()

    # Hyperparameter search space
    d_model = trial.suggest_categorical('d_model', [32, 64, 128])
    nhead = trial.suggest_categorical('nhead', [2, 4, 8])
    num_layers = trial.suggest_int('num_layers', 1, 4)
    dropout = trial.suggest_float('dropout', 0.05, 0.3)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])

    # Model and training components
    model = TransformerTimeSeries(d_model=d_model, nhead=nhead, num_layers=num_layers, dropout=dropout).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

    # Proper train/val split BEFORE wrapping into TensorDataset
    val_ratio = 0.1
    val_size = int(len(X_train) * val_ratio)
    train_size = len(X_train) - val_size

    X_train_actual = X_train[:train_size]
    y_train_actual = y_train[:train_size]
    X_val = X_train[train_size:]
    y_val = y_train[train_size:]

    train_dataset = TensorDataset(X_train_actual, y_train_actual)
    val_dataset = TensorDataset(X_val, y_val)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Early stopping parameters
    early_stopping_patience = 5
    best_val_loss = float('inf')
    epochs_no_improve = 0
    max_epochs = 50

    for epoch in range(max_epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                loss = criterion(pred, yb)
                val_losses.append(loss.item())
        val_loss = sum(val_losses) / len(val_losses)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= early_stopping_patience:
            break

    return best_val_loss

# %%
set_seeds(42)

sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study
. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:11:42,237] Trial 13 finished with value: 0.003595069225411862 and parameters: {'d_model': 32, 'nhead': 8, 'num_layers': 2, 'dropout': 0.14881279712622614, 'lr': 0.0022058917252804127, 'batch_size': 32}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:18:16,125] Trial 14 finished with value: 0.0029172031790949404 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.09675696332332591, 'lr': 0.0009471446139450116, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:24:09,156] Trial 15 finished with value: 0.00306582372286357 and parameters: {'d_model': 32, 'nhead': 4, 'num_layers': 2, 'dropout': 0.1888729762910701, 'lr': 0.00030763658173760917, 'batch_size': 32}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:29:11,916] Trial 16 finished with value: 0.050864859484136105 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 4, 'dropout': 0.050774171216991404, 'lr': 0.009565855674522866, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:35:17,424] Trial 17 finished with value: 0.003064914984861389 and parameters: {'d_model': 64, 'nhead': 8, 'num_layers': 3, 'dropout': 0.14623727545861362, 'lr': 0.0007164479508598226, 'batch_size': 32}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:42:55,612] Trial 18 finished with value: 0.0032951253233477473 and parameters: {'d_model': 32, 'nhead': 4, 'num_layers': 2, 'dropout': 0.09002962428332036, 'lr': 0.00010740407619157729, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:48:51,511] Trial 19 finished with value: 0.0036235018633306026 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.20649948120661704, 'lr': 0.0020950697759902215, 'batch_size': 16}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:52:56,870] Trial 20 finished with value: 0.00337661721277982 and parameters: {'d_model': 32, 'nhead': 8, 'num_layers': 2, 'dropout': 0.15378216312372914, 'lr': 0.00027841505385467144, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 14:59:30,565] Trial 21 finished with value: 0.002928293601144105 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.0999438182748441, 'lr': 0.0010046677582665844, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 15:03:35,640] Trial 22 finished with value: 0.0033642163616605103 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.08034392940506714, 'lr': 0.0016155377070117781, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 15:11:04,767] Trial 23 finished with value: 0.003291489469120279 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.11835049760875013, 'lr': 0.000721200140571461, 'batch_size': 64}. Best is trial 2 with value: 0.0027546874480322003.
# [I 2025-05-26 15:19:54,187] Trial 24 finished with value: 0.002662034094100818 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.10466791003062924, 'lr': 0.0002506533022548194, 'batch_size': 64}. Best is trial 24 with value: 0.002662034094100818.

# %%
batch_size = best_params['batch_size']
model = TransformerTimeSeries(
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_layers=best_params['num_layers'],
    dropout=best_params['dropout']
).to(device)

criterion = nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])
optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=1e-5)

# %%
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

max_epochs = 100  # Set to a reasonable fixed value

print("Starting final training on full training data...")

for epoch in range(max_epochs):
    model.train()
    epoch_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_loss += loss.item() * xb.size(0)
    epoch_loss /= len(train_loader.dataset)

    print(f"Epoch {epoch+1}/{max_epochs} Train Loss: {epoch_loss:.6f}")

# No model.load_state_dict() — we're training fully without early stopping
# Out:
# Starting final training on full training data...
# Epoch 1/100 Train Loss: 0.002446
# Epoch 2/100 Train Loss: 0.002799
# Epoch 3/100 Train Loss: 0.002303
# Epoch 4/100 Train Loss: 0.002555
# Epoch 5/100 Train Loss: 0.002466
# Epoch 6/100 Train Loss: 0.002530
# Epoch 7/100 Train Loss: 0.002443
# Epoch 8/100 Train Loss: 0.002409
# Epoch 9/100 Train Loss: 0.002422
# Epoch 10/100 Train Loss: 0.002413
# Epoch 11/100 Train Loss: 0.002516
# Epoch 12/100 Train Loss: 0.002529
# Epoch 13/100 Train Loss: 0.002321
# Epoch 14/100 Train Loss: 0.002319
# Epoch 15/100 Train Loss: 0.002340
# Epoch 16/100 Train Loss: 0.002597
# Epoch 17/100 Train Loss: 0.002919
# Epoch 18/100 Train Loss: 0.002414
# Epoch 19/100 Train Loss: 0.002458
# Epoch 20/100 Train Loss: 0.002342
# Epoch 21/100 Train Loss: 0.002380
# Epoch 22/100 Train Loss: 0.002582
# Epoch 23/100 Train Loss: 0.002311
# Epoch 24/100 Train Loss: 0.002267
# Epoch 25/100 Train Loss: 0.002349
# Epoch 26/100 Train Loss: 0.002179
# Epoch 27/100 Train Loss: 0.002210
# Epoch 28/100 Train Loss: 0.002346
# Epoch 29/100 Train Loss: 0.002258
# Epoch 30/100 Train Loss: 0.002435
# Epoch 31/100 Train Loss: 0.002215
# Epoch 32/100 Train Loss: 0.002369
# Epoch 33/100 Train Loss: 0.002166
# Epoch 34/100 Train Loss: 0.002263
# Epoch 35/100 Train Loss: 0.002607
# Epoch 36/100 Train Loss: 0.002330
# Epoch 37/100 Train Loss: 0.002100
# Epoch 38/100 Train Loss: 0.002182
# Epoch 39/100 Train Loss: 0.002245
# Epoch 40/100 Train Loss: 0.002315
# Epoch 41/100 Train Loss: 0.002457
# Epoch 42/100 Train Loss: 0.002111
# Epoch 43/100 Train Loss: 0.002080
# Epoch 44/100 Train Loss: 0.002044
# Epoch 45/100 Train Loss: 0.002299
# Epoch 46/100 Train Loss: 0.002109
# Epoch 47/100 Train Loss: 0.002201
# Epoch 48/100 Train Loss: 0.002105
# Epoch 49/100 Train Loss: 0.002142
# Epoch 50/100 Train Loss: 0.002123
# Epoch 51/100 Train Loss: 0.001908
# Epoch 52/100 Train Loss: 0.001993
# Epoch 53/100 Train Loss: 0.002157
# Epoch 54/100 Train Loss: 0.002220
# Epoch 55/100 Train Loss: 0.002065
# Epoch 56/100 Train Loss: 0.002118
# Epoch 57/100 Train Loss: 0.002001
# Epoch 58/100 Train Loss: 0.002120
# Epoch 59/100 Train Loss: 0.002152
# Epoch 60/100 Train Loss: 0.002016
# Epoch 61/100 Train Loss: 0.002021
# Epoch 62/100 Train Loss: 0.002138
# Epoch 63/100 Train Loss: 0.002017
# Epoch 64/100 Train Loss: 0.002009
# Epoch 65/100 Train Loss: 0.002135
# Epoch 66/100 Train Loss: 0.002038
# Epoch 67/100 Train Loss: 0.002012
# Epoch 68/100 Train Loss: 0.002272
# Epoch 69/100 Train Loss: 0.002304
# Epoch 70/100 Train Loss: 0.002254
# Epoch 71/100 Train Loss: 0.002042
# Epoch 72/100 Train Loss: 0.001844
# Epoch 73/100 Train Loss: 0.002089
# Epoch 74/100 Train Loss: 0.002125
# Epoch 75/100 Train Loss: 0.001907
# Epoch 76/100 Train Loss: 0.001867
# Epoch 77/100 Train Loss: 0.001848
# Epoch 78/100 Train Loss: 0.001890
# Epoch 79/100 Train Loss: 0.002066
# Epoch 80/100 Train Loss: 0.001958
# Epoch 81/100 Train Loss: 0.001853
# Epoch 82/100 Train Loss: 0.001842
# Epoch 83/100 Train Loss: 0.001818
# Epoch 84/100 Train Loss: 0.001814
# Epoch 85/100 Train Loss: 0.001880
# Epoch 86/100 Train Loss: 0.001900
# Epoch 87/100 Train Loss: 0.001859
# Epoch 88/100 Train Loss: 0.001867
# Epoch 89/100 Train Loss: 0.001808
# Epoch 90/100 Train Loss: 0.001959
# Epoch 91/100 Train Loss: 0.001827
# Epoch 92/100 Train Loss: 0.001883
# Epoch 93/100 Train Loss: 0.001836
# Epoch 94/100 Train Loss: 0.001833
# Epoch 95/100 Train Loss: 0.001939
# Epoch 96/100 Train Loss: 0.001855
# Epoch 97/100 Train Loss: 0.001817
# Epoch 98/100 Train Loss: 0.001938
# Epoch 99/100 Train Loss: 0.001789
# Epoch 100/100 Train Loss: 0.001804

# %%
train_pred_inv, y_train_inv, train_rmse = evaluate(model, train_loader, scaler)
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 4.2849

# %%
pred_path = "predictions/Traffic_Transformer_train.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, train_pred_inv)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_train_raw.index[-len(train_pred_inv):], y_train_inv, label='Actual')
plt.plot(df_train_raw.index[-len(train_pred_inv):], train_pred_inv, label='Transformer Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Traffic')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size)
test_pred_inv, y_test_inv, test_rmse = evaluate(model, test_loader, scaler)
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 4.4650

# %%
dataset_name = "Traffic"
rmse_file = "RMSE_Transformer.json"
try:
    with open(rmse_file, "r") as f:
        rmse_data = json.load(f)
except FileNotFoundError:
    rmse_data = {}

rmse_data[dataset_name] = round(test_rmse, 2)
with open(rmse_file, "w") as f:
    json.dump(rmse_data, f, indent=4)

# %%
pred_path = "predictions/Traffic_Transformer_test.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, test_pred_inv)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test_raw.index[-len(test_pred_inv):], y_test_inv, label='Actual')
plt.plot(df_test_raw.index[-len(test_pred_inv):], test_pred_inv, label='Transformer Predicted')
plt.title('Actual vs Predicted Traffic (Test Set)')
plt.xlabel('Date')
plt.ylabel('Traffic')
plt.legend()
plt.show()
