# %%
import os
import json
import math
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
import torch
import random
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from torch.utils.data import DataLoader, TensorDataset
import optuna

# %%
def set_seeds(seed=42):
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_excel("../datasets/AEP_hourly_processed.xlsx")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df["Datetime"] = pd.to_datetime(df["Datetime"])
df = df.sort_values("Datetime")
df.set_index("Datetime", inplace=True)
df = df[["AEP_MW"]]
df = df.iloc[:5000]

train_size = int(len(df) * 0.8)
df_train_raw = df.iloc[:train_size]
df_test_raw = df.iloc[train_size:]

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(df_train_raw)
scaled_test = scaler.transform(df_test_raw)

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i-seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train = create_sequences(scaled_train)
X_test, y_test = create_sequences(scaled_test)

X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(-1)
y_train = torch.tensor(y_train, dtype=torch.float32).unsqueeze(-1)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(-1)
y_test = torch.tensor(y_test, dtype=torch.float32).unsqueeze(-1)

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return x

# %%
class TransformerTimeSeries(nn.Module):
    def __init__(self, feature_size=1, d_model=64, nhead=2, num_layers=1, dropout=0.1):
        super().__init__()
        self.input_linear = nn.Linear(feature_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model)
        encoder_layers = nn.TransformerEncoderLayer(d_model=d_model, nhead=nhead, dropout=dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers=num_layers)
        self.decoder = nn.Linear(d_model, 1)

    def forward(self, src):
        x = self.input_linear(src)
        x = self.pos_encoder(x)
        x = self.transformer_encoder(x)
        out = self.decoder(x[:, -1, :])
        return out

device = torch.device("cpu")

# %%
def evaluate(model, loader, scaler):
    model.eval()
    preds = []
    actuals = []
    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(device)
            pred = model(xb).cpu().numpy()
            preds.append(pred)
            actuals.append(yb.numpy())
    preds = np.vstack(preds)
    actuals = np.vstack(actuals)
    preds_inv = scaler.inverse_transform(preds)
    actuals_inv = scaler.inverse_transform(actuals)
    rmse = math.sqrt(mean_squared_error(actuals_inv, preds_inv))
    return preds_inv, actuals_inv, rmse

# %%
def objective(trial):
    set_seeds()

    # Hyperparameter search space
    d_model = trial.suggest_categorical('d_model', [32, 64, 128])
    nhead = trial.suggest_categorical('nhead', [2, 4, 8])
    num_layers = trial.suggest_int('num_layers', 1, 4)
    dropout = trial.suggest_float('dropout', 0.05, 0.3)
    lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])

    # Model and training components
    model = TransformerTimeSeries(d_model=d_model, nhead=nhead, num_layers=num_layers, dropout=dropout).to(device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-5)

    # Proper train/val split BEFORE wrapping into TensorDataset
    val_ratio = 0.1
    val_size = int(len(X_train) * val_ratio)
    train_size = len(X_train) - val_size

    X_train_actual = X_train[:train_size]
    y_train_actual = y_train[:train_size]
    X_val = X_train[train_size:]
    y_val = y_train[train_size:]

    train_dataset = TensorDataset(X_train_actual, y_train_actual)
    val_dataset = TensorDataset(X_val, y_val)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Early stopping parameters
    early_stopping_patience = 5
    best_val_loss = float('inf')
    epochs_no_improve = 0
    max_epochs = 50

    for epoch in range(max_epochs):
        model.train()
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                loss = criterion(pred, yb)
                val_losses.append(loss.item())
        val_loss = sum(val_losses) / len(val_losses)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve >= early_stopping_patience:
            break

    return best_val_loss

# %%
set_seeds(42)

sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study
and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.14270494521064878, 'lr': 0.0002782705237135121, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:02:15,921] Trial 14 finished with value: 0.0007532673771493137 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 3, 'dropout': 0.05242996889164959, 'lr': 0.0010676916501410137, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:12:46,990] Trial 15 finished with value: 0.0006423807152224561 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.08771658894939538, 'lr': 0.00011709441166306263, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:30:28,645] Trial 16 finished with value: 0.0006543074750180284 and parameters: {'d_model': 32, 'nhead': 4, 'num_layers': 3, 'dropout': 0.17082407519817117, 'lr': 0.00011528771920445441, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:37:36,658] Trial 17 finished with value: 0.0007811191026121378 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.09182300294647362, 'lr': 0.0001928522959838374, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:43:59,161] Trial 18 finished with value: 0.0007789434222594047 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.15181442026680964, 'lr': 0.00010247444391360779, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 20:51:22,958] Trial 19 finished with value: 0.0009915304972673766 and parameters: {'d_model': 64, 'nhead': 4, 'num_layers': 4, 'dropout': 0.20649948120661704, 'lr': 0.00023072063857885138, 'batch_size': 16}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 21:01:52,422] Trial 20 finished with value: 0.0007157506703291661 and parameters: {'d_model': 32, 'nhead': 2, 'num_layers': 3, 'dropout': 0.08600856668517448, 'lr': 0.0007481534382760826, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 21:08:59,650] Trial 21 finished with value: 0.0007349086775390718 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.07124308237486203, 'lr': 0.0004069234981824579, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 21:16:07,289] Trial 22 finished with value: 0.0007488028540347631 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.11886089678086777, 'lr': 0.0006284589409601459, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 21:23:19,752] Trial 23 finished with value: 0.0006822857450550565 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 4, 'dropout': 0.09809876956787839, 'lr': 0.0001810890577637778, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.
# [I 2025-05-26 21:36:21,490] Trial 24 finished with value: 0.0005557418044190854 and parameters: {'d_model': 64, 'nhead': 2, 'num_layers': 3, 'dropout': 0.0664601626598754, 'lr': 0.00025914129992908656, 'batch_size': 32}. Best is trial 2 with value: 0.0005435758133759149.

# %%
batch_size = best_params['batch_size']
model = TransformerTimeSeries(
    d_model=best_params['d_model'],
    nhead=best_params['nhead'],
    num_layers=best_params['num_layers'],
    dropout=best_params['dropout']
).to(device)

criterion = nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'])
optimizer = torch.optim.Adam(model.parameters(), lr=best_params['lr'], weight_decay=1e-5)

# %%
train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

max_epochs = 100  # Set to a reasonable fixed value

print("Starting final training on full training data...")

for epoch in range(max_epochs):
    model.train()
    epoch_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_loss += loss.item() * xb.size(0)
    epoch_loss /= len(train_loader.dataset)

    print(f"Epoch {epoch+1}/{max_epochs} Train Loss: {epoch_loss:.6f}")

# No model.load_state_dict() — we're training fully without early stopping
# Out:
# Starting final training on full training data...
# Epoch 1/100 Train Loss: 0.032541
# Epoch 2/100 Train Loss: 0.003608
# Epoch 3/100 Train Loss: 0.002286
# Epoch 4/100 Train Loss: 0.001856
# Epoch 5/100 Train Loss: 0.001946
# Epoch 6/100 Train Loss: 0.001451
# Epoch 7/100 Train Loss: 0.001370
# Epoch 8/100 Train Loss: 0.001327
# Epoch 9/100 Train Loss: 0.001179
# Epoch 10/100 Train Loss: 0.001182
# Epoch 11/100 Train Loss: 0.001005
# Epoch 12/100 Train Loss: 0.001275
# Epoch 13/100 Train Loss: 0.001067
# Epoch 14/100 Train Loss: 0.001146
# Epoch 15/100 Train Loss: 0.000913
# Epoch 16/100 Train Loss: 0.001086
# Epoch 17/100 Train Loss: 0.000989
# Epoch 18/100 Train Loss: 0.000811
# Epoch 19/100 Train Loss: 0.000949
# Epoch 20/100 Train Loss: 0.000996
# Epoch 21/100 Train Loss: 0.000834
# Epoch 22/100 Train Loss: 0.000830
# Epoch 23/100 Train Loss: 0.000899
# Epoch 24/100 Train Loss: 0.000814
# Epoch 25/100 Train Loss: 0.000803
# Epoch 26/100 Train Loss: 0.000726
# Epoch 27/100 Train Loss: 0.000760
# Epoch 28/100 Train Loss: 0.000745
# Epoch 29/100 Train Loss: 0.000776
# Epoch 30/100 Train Loss: 0.000713
# Epoch 31/100 Train Loss: 0.000840
# Epoch 32/100 Train Loss: 0.000748
# Epoch 33/100 Train Loss: 0.000695
# Epoch 34/100 Train Loss: 0.000677
# Epoch 35/100 Train Loss: 0.000665
# Epoch 36/100 Train Loss: 0.000718
# Epoch 37/100 Train Loss: 0.000705
# Epoch 38/100 Train Loss: 0.000741
# Epoch 39/100 Train Loss: 0.000679
# Epoch 40/100 Train Loss: 0.000674
# Epoch 41/100 Train Loss: 0.000755
# Epoch 42/100 Train Loss: 0.000567
# Epoch 43/100 Train Loss: 0.000607
# Epoch 44/100 Train Loss: 0.000703
# Epoch 45/100 Train Loss: 0.000646
# Epoch 46/100 Train Loss: 0.000697
# Epoch 47/100 Train Loss: 0.000633
# Epoch 48/100 Train Loss: 0.000616
# Epoch 49/100 Train Loss: 0.000542
# Epoch 50/100 Train Loss: 0.000565
# Epoch 51/100 Train Loss: 0.000610
# Epoch 52/100 Train Loss: 0.000612
# Epoch 53/100 Train Loss: 0.000577
# Epoch 54/100 Train Loss: 0.000571
# Epoch 55/100 Train Loss: 0.000529
# Epoch 56/100 Train Loss: 0.000510
# Epoch 57/100 Train Loss: 0.000502
# Epoch 58/100 Train Loss: 0.000538
# Epoch 59/100 Train Loss: 0.000502
# Epoch 60/100 Train Loss: 0.000535
# Epoch 61/100 Train Loss: 0.000500
# Epoch 62/100 Train Loss: 0.000532
# Epoch 63/100 Train Loss: 0.000459
# Epoch 64/100 Train Loss: 0.000479
# Epoch 65/100 Train Loss: 0.000504
# Epoch 66/100 Train Loss: 0.000472
# Epoch 67/100 Train Loss: 0.000450
# Epoch 68/100 Train Loss: 0.000463
# Epoch 69/100 Train Loss: 0.000439
# Epoch 70/100 Train Loss: 0.000473
# Epoch 71/100 Train Loss: 0.000470
# Epoch 72/100 Train Loss: 0.000428
# Epoch 73/100 Train Loss: 0.000483
# Epoch 74/100 Train Loss: 0.000496
# Epoch 75/100 Train Loss: 0.000397
# Epoch 76/100 Train Loss: 0.000378
# Epoch 77/100 Train Loss: 0.000379
# Epoch 78/100 Train Loss: 0.000382
# Epoch 79/100 Train Loss: 0.000411
# Epoch 80/100 Train Loss: 0.000421
# Epoch 81/100 Train Loss: 0.000386
# Epoch 82/100 Train Loss: 0.000394
# Epoch 83/100 Train Loss: 0.000386
# Epoch 84/100 Train Loss: 0.000393
# Epoch 85/100 Train Loss: 0.000369
# Epoch 86/100 Train Loss: 0.000384
# Epoch 87/100 Train Loss: 0.000339
# Epoch 88/100 Train Loss: 0.000351
# Epoch 89/100 Train Loss: 0.000348
# Epoch 90/100 Train Loss: 0.000382
# Epoch 91/100 Train Loss: 0.000353
# Epoch 92/100 Train Loss: 0.000362
# Epoch 93/100 Train Loss: 0.000373
# Epoch 94/100 Train Loss: 0.000350
# Epoch 95/100 Train Loss: 0.000314
# Epoch 96/100 Train Loss: 0.000350
# Epoch 97/100 Train Loss: 0.000331
# Epoch 98/100 Train Loss: 0.000353
# Epoch 99/100 Train Loss: 0.000350
# Epoch 100/100 Train Loss: 0.000330

# %%
train_pred_inv, y_train_inv, train_rmse = evaluate(model, train_loader, scaler)
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 207.2192

# %%
pred_path = "predictions/Energy_Transformer_train.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, train_pred_inv)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_train_raw.index[-len(train_pred_inv):], y_train_inv, label='Actual')
plt.plot(df_train_raw.index[-len(train_pred_inv):], train_pred_inv, label='Transformer Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Energy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size)
test_pred_inv, y_test_inv, test_rmse = evaluate(model, test_loader, scaler)
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 325.9232

# %%
dataset_name = "Energy"
rmse_file = "RMSE_Transformer.json"
try:
    with open(rmse_file, "r") as f:
        rmse_data = json.load(f)
except FileNotFoundError:
    rmse_data = {}

rmse_data[dataset_name] = round(test_rmse, 2)
with open(rmse_file, "w") as f:
    json.dump(rmse_data, f, indent=4)

# %%
pred_path = "predictions/Energy_Transformer_test.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, test_pred_inv)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test_raw.index[-len(test_pred_inv):], y_test_inv, label='Actual')
plt.plot(df_test_raw.index[-len(test_pred_inv):], test_pred_inv, label='Transformer Predicted')
plt.title('Actual vs Predicted Energy Consumed (Test Set)')
plt.xlabel('Date')
plt.ylabel('Energy')
plt.legend()
plt.show()
