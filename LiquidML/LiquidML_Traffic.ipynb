# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import shutil
import warnings
import os
import json
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import optuna
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from liquidnet.main import LiquidNet
import random

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
df = pd.read_excel("../datasets/traffic.xlsx")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df["DateTime"] = pd.to_datetime(df["DateTime"])
df.set_index("DateTime", inplace=True)
df = df[["Vehicles"]]
df = df.iloc[-3000:]

train_size = int(len(df) * 0.8)
df_train_raw = df.iloc[:train_size]
df_test_raw = df.iloc[train_size:]

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(df_train_raw)
scaled_test = scaler.transform(df_test_raw)

df_train = pd.DataFrame(scaled_train, columns=df.columns, index=df_train_raw.index)
df_test = pd.DataFrame(scaled_test, columns=df.columns, index=df_test_raw.index)

print(f"Training data size: {len(df_train)}")
print(f"Testing data size: {len(df_test)}")
# Out:
# Training data size: 2400
# Testing data size: 600

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i - seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train_np, y_train_np = create_sequences(scaled_train)
X_test_np, y_test_np = create_sequences(scaled_test)

X_train = torch.tensor(X_train_np, dtype=torch.float32)
y_train = torch.tensor(y_train_np, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np, dtype=torch.float32).unsqueeze(1)

val_size = int(0.1 * len(X_train))
X_val, y_val = X_train[-val_size:], y_train[-val_size:]
X_train_final, y_train_final = X_train[:-val_size], y_train[:-val_size]

# %%
def train(model, optimizer, criterion, train_loader, val_loader=None, epochs=50, patience=5):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        train_losses = []
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch) 
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        if val_loader is not None:
            model.eval()
            val_losses = []
            with torch.no_grad():
                for X_val_batch, y_val_batch in val_loader:
                    val_outputs = model(X_val_batch) 
                    val_loss = criterion(val_outputs, y_val_batch)
                    val_losses.append(val_loss.item())
            avg_val_loss = sum(val_losses) / len(val_losses)
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}, Val Loss: {avg_val_loss:.4f}")

            if avg_val_loss < best_loss:
                best_loss = avg_val_loss
                best_model_state = model.state_dict()
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered at epoch {epoch+1}")
                    break
        else:
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}")
            best_model_state = model.state_dict()

    if best_model_state:
        model.load_state_dict(best_model_state)
    return best_loss if val_loader else None

# %%
def objective(trial):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    hidden_size = trial.suggest_int("hidden_size", 32, 128)
    lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128])
    hidden_dim = trial.suggest_int("hidden_dim", 64, 256)

    input_dim = X_train.shape[1]

    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    dropout_rate = trial.suggest_float("dropout", 0.1, 0.5)


    class LiquidNetWithOutput(nn.Module):
        def __init__(self, num_units, output_dim):
            super().__init__()
            self.liquid_net = LiquidNet(num_units=num_units)
            self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Dropout(dropout_rate), nn.Linear(64, output_dim))

        def forward(self, inputs):
            batch_size = inputs.shape[0]
            h0 = torch.zeros(batch_size, self.liquid_net.state_size).to(inputs.device)
            ln_outputs, _ = self.liquid_net(inputs, h0)
            return self.output_layer(ln_outputs)

    model = LiquidNetWithOutput(num_units=hidden_dim, output_dim=1)

    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=False)
    criterion = nn.MSELoss()

    train_dataset = TensorDataset(X_train_final, y_train_final)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    best_val_loss = float("inf")
    patience = 10
    wait = 0

    for epoch in range(50):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = criterion(output, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(X_val).numpy()
            y_val_np = y_val.cpu().numpy()

            val_preds_inv = scaler.inverse_transform(val_preds)
            y_val_inv = scaler.inverse_transform(y_val_np)

            val_rmse = mean_squared_error(y_val_inv, val_preds_inv, squared=False)

        scheduler.step(val_rmse)

        if val_rmse < best_val_loss:
            best_val_loss = val_rmse
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)

best_params = study.best_params
print(f"Best hyperparameters: {best_params}")
# Out:
# [I 2025-05-25 11:57:03,828] A new study created in memory with name: no-name-795af7e8-4c01-4cb9-a107-012ab1b28152
# [I 2025-05-25 12:02:39,266] Trial 0 finished with value: 6.58389139175415 and parameters: {'hidden_size': 94, 'lr': 0.0007228103803499281, 'batch_size': 128, 'hidden_dim': 177, 'weight_decay': 4.629310107203321e-06, 'dropout': 0.1414864374586997}. Best is trial 0 with value: 6.58389139175415.
# [I 2025-05-25 12:11:53,860] Trial 1 finished with value: 14.886483192443848 and parameters: {'hidden_size': 126, 'lr': 3.371907476049523e-05, 'batch_size': 128, 'hidden_dim': 233, 'weight_decay': 2.3582862597888716e-06, 'dropout': 0.29897903824679517}. Best is trial 0 with value: 6.58389139175415.
# [I 2025-05-25 12:16:19,660] Trial 2 finished with value: 6.068603992462158 and parameters: {'hidden_size': 83, 'lr': 0.0020383326437475014, 'batch_size': 64, 'hidden_dim': 159, 'weight_decay': 2.4577413063560587e-06, 'dropout': 0.22976910459385624}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:26:03,008] Trial 3 finished with value: 14.397688865661621 and parameters: {'hidden_size': 99, 'lr': 4.459964304082364e-05, 'batch_size': 128, 'hidden_dim': 239, 'weight_decay': 0.0005171464945115348, 'dropout': 0.41000175062780886}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:35:46,821] Trial 4 finished with value: 6.810544490814209 and parameters: {'hidden_size': 34, 'lr': 0.0011553902670576445, 'batch_size': 128, 'hidden_dim': 239, 'weight_decay': 0.00029906171827068424, 'dropout': 0.38567548404394936}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:42:03,190] Trial 5 finished with value: 7.149185657501221 and parameters: {'hidden_size': 110, 'lr': 0.00032603507333247455, 'batch_size': 128, 'hidden_dim': 192, 'weight_decay': 1.5825544878223441e-06, 'dropout': 0.435808001004632}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:49:54,386] Trial 6 finished with value: 6.984616756439209 and parameters: {'hidden_size': 84, 'lr': 0.0016445245940060755, 'batch_size': 64, 'hidden_dim': 233, 'weight_decay': 0.0009530850874731027, 'dropout': 0.18051955566921132}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:57:33,305] Trial 7 finished with value: 6.249383449554443 and parameters: {'hidden_size': 128, 'lr': 0.0016113035095004858, 'batch_size': 128, 'hidden_dim': 217, 'weight_decay': 8.546827721461433e-05, 'dropout': 0.38913818584836746}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 12:59:50,605] Trial 8 finished with value: 11.451842308044434 and parameters: {'hidden_size': 42, 'lr': 0.0022456828962709834, 'batch_size': 32, 'hidden_dim': 145, 'weight_decay': 0.008744431914171855, 'dropout': 0.38151794225}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:00:29,282] Trial 9 finished with value: 6.453691482543945 and parameters: {'hidden_size': 118, 'lr': 0.001673385942694323, 'batch_size': 32, 'hidden_dim': 88, 'weight_decay': 1.765955320954689e-06, 'dropout': 0.29655304866007826}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:02:29,200] Trial 10 finished with value: 6.27146577835083 and parameters: {'hidden_size': 56, 'lr': 0.007994239565013593, 'batch_size': 64, 'hidden_dim': 134, 'weight_decay': 2.177968601795962e-05, 'dropout': 0.22019892479498718}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:07:32,964] Trial 11 finished with value: 6.950253486633301 and parameters: {'hidden_size': 66, 'lr': 0.008624697162419382, 'batch_size': 64, 'hidden_dim': 193, 'weight_decay': 2.986611583451283e-05, 'dropout': 0.48139735541190476}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:09:24,223] Trial 12 finished with value: 9.13994312286377 and parameters: {'hidden_size': 71, 'lr': 0.00016179876473224858, 'batch_size': 64, 'hidden_dim': 113, 'weight_decay': 1.6339636160647168e-05, 'dropout': 0.24077483830673635}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:11:34,907] Trial 13 finished with value: 7.063728332519531 and parameters: {'hidden_size': 102, 'lr': 0.004421558348684409, 'batch_size': 64, 'hidden_dim': 166, 'weight_decay': 0.00010201429304943471, 'dropout': 0.3445022477011744}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:19:01,847] Trial 14 finished with value: 8.242681503295898 and parameters: {'hidden_size': 84, 'lr': 0.000316812537391985, 'batch_size': 32, 'hidden_dim': 212, 'weight_decay': 0.003781329058005098, 'dropout': 0.10204443599787533}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:21:34,663] Trial 15 finished with value: 7.313089370727539 and parameters: {'hidden_size': 128, 'lr': 0.0006128000173616458, 'batch_size': 128, 'hidden_dim': 121, 'weight_decay': 9.710149248472426e-05, 'dropout': 0.25582848292853627}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:28:52,920] Trial 16 finished with value: 7.914560317993164 and parameters: {'hidden_size': 55, 'lr': 0.00012916774264797355, 'batch_size': 64, 'hidden_dim': 209, 'weight_decay': 6.293380337658972e-06, 'dropout': 0.4927359713488862}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:29:40,970] Trial 17 finished with value: 29.122276306152344 and parameters: {'hidden_size': 75, 'lr': 1.0535049610651121e-05, 'batch_size': 128, 'hidden_dim': 75, 'weight_decay': 7.532286449531994e-05, 'dropout': 0.3393482761342067}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:33:44,806] Trial 18 finished with value: 6.275644302368164 and parameters: {'hidden_size': 113, 'lr': 0.0031001389749035287, 'batch_size': 64, 'hidden_dim': 155, 'weight_decay': 7.964090513854814e-06, 'dropout': 0.19195117999438602}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:38:47,725] Trial 19 finished with value: 7.568804740905762 and parameters: {'hidden_size': 91, 'lr': 0.004489084568492275, 'batch_size': 32, 'hidden_dim': 180, 'weight_decay': 0.0017491278278891347, 'dropout': 0.27608392183244396}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:46:02,326] Trial 20 finished with value: 6.988217353820801 and parameters: {'hidden_size': 62, 'lr': 0.0007012424989019325, 'batch_size': 128, 'hidden_dim': 210, 'weight_decay': 0.00031886271306742677, 'dropout': 0.336921324785592}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:48:59,673] Trial 21 finished with value: 6.641170501708984 and parameters: {'hidden_size': 56, 'lr': 0.009746111878030754, 'batch_size': 64, 'hidden_dim': 135, 'weight_decay': 3.0055536236164914e-05, 'dropout': 0.20704426740528564}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 13:50:11,986] Trial 22 finished with value: 6.425228118896484 and parameters: {'hidden_size': 49, 'lr': 0.00575038677734038, 'batch_size': 64, 'hidden_dim': 112, 'weight_decay': 1.6019906086527284e-05, 'dropout': 0.21116984996004995}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:00:25,487] Trial 23 finished with value: 6.256021499633789 and parameters: {'hidden_size': 34, 'lr': 0.0031479832010288147, 'batch_size': 64, 'hidden_dim': 256, 'weight_decay': 4.922777713796696e-05, 'dropout': 0.23242142855574618}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:11:19,169] Trial 24 finished with value: 6.110228538513184 and parameters: {'hidden_size': 43, 'lr': 0.0028597522753900637, 'batch_size': 64, 'hidden_dim': 256, 'weight_decay': 4.874608699358053e-05, 'dropout': 0.16004489302599956}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:21:25,638] Trial 25 finished with value: 6.210944175720215 and parameters: {'hidden_size': 78, 'lr': 0.0013134306915535655, 'batch_size': 64, 'hidden_dim': 248, 'weight_decay': 0.00017784134555807313, 'dropout': 0.14708533669552912}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:31:53,082] Trial 26 finished with value: 6.494536876678467 and parameters: {'hidden_size': 78, 'lr': 0.0009578913765306004, 'batch_size': 64, 'hidden_dim': 252, 'weight_decay': 0.00019563168956900637, 'dropout': 0.15800730480273908}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:40:13,844] Trial 27 finished with value: 6.898059368133545 and parameters: {'hidden_size': 69, 'lr': 0.0005142276190491656, 'batch_size': 64, 'hidden_dim': 223, 'weight_decay': 0.0007959566136212148, 'dropout': 0.10440506616092637}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:44:48,010] Trial 28 finished with value: 6.360703468322754 and parameters: {'hidden_size': 44, 'lr': 0.00255156648393146, 'batch_size': 64, 'hidden_dim': 193, 'weight_decay': 0.0002041007723056257, 'dropout': 0.13689024578167241}. Best is trial 2 with value: 6.068603992462158.
# [I 2025-05-25 14:50:04,734] Trial 29 finished with value: 5.935915470123291 and parameters: {'hidden_size': 91, 'lr': 0.0010164316230609261, 'batch_size': 64, 'hidden_dim': 174, 'weight_decay': 9.78369768087374e-06, 'dropout': 0.15101578865779214}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 14:55:34,042] Trial 30 finished with value: 7.481399059295654 and parameters: {'hidden_size': 90, 'lr': 0.00017306247647929648, 'batch_size': 64, 'hidden_dim': 173, 'weight_decay': 4.590235291477071e-06, 'dropout': 0.16929482287824452}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 14:59:16,165] Trial 31 finished with value: 6.924821376800537 and parameters: {'hidden_size': 100, 'lr': 0.0010625980666976568, 'batch_size': 64, 'hidden_dim': 155, 'weight_decay': 3.6561540071846108e-06, 'dropout': 0.13700171148100024}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:09:53,474] Trial 32 finished with value: 6.086474895477295 and parameters: {'hidden_size': 81, 'lr': 0.00046598366105335263, 'batch_size': 64, 'hidden_dim': 247, 'weight_decay': 9.818130672972695e-06, 'dropout': 0.13115310277387532}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:15:34,336] Trial 33 finished with value: 9.33005142211914 and parameters: {'hidden_size': 94, 'lr': 8.370293674074357e-05, 'batch_size': 64, 'hidden_dim': 179, 'weight_decay': 1.0191067179017003e-06, 'dropout': 0.11936656726028264}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:24:43,433] Trial 34 finished with value: 6.188513278961182 and parameters: {'hidden_size': 86, 'lr': 0.0005069995635782401, 'batch_size': 64, 'hidden_dim': 231, 'weight_decay': 1.097553781609584e-05, 'dropout': 0.18777465719668027}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:34:26,579] Trial 35 finished with value: 6.000421047210693 and parameters: {'hidden_size': 97, 'lr': 0.0008023120264567742, 'batch_size': 64, 'hidden_dim': 243, 'weight_decay': 3.276722471251473e-06, 'dropout': 0.12635752291822253}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:41:20,062] Trial 36 finished with value: 6.717135429382324 and parameters: {'hidden_size': 103, 'lr': 0.0002526572110253463, 'batch_size': 64, 'hidden_dim': 203, 'weight_decay': 2.496119062891156e-06, 'dropout': 0.12169229100322815}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 15:51:35,147] Trial 37 finished with value: 5.9556660652160645 and parameters: {'hidden_size': 106, 'lr': 0.00045924108369619845, 'batch_size': 32, 'hidden_dim': 242, 'weight_decay': 1.0399659932947818e-06, 'dropout': 0.12609677197837343}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 16:00:48,056] Trial 38 finished with value: 6.249384880065918 and parameters: {'hidden_size': 106, 'lr': 0.0008546336112679388, 'batch_size': 32, 'hidden_dim': 229, 'weight_decay': 1.0197725866127428e-06, 'dropout': 0.17474721331474402}. Best is trial 29 with value: 5.935915470123291.
# [I 2025-05-25 16:10:35,121] Trial 39 finished with value: 5.911322593688965 and parameters: {'hidden_size': 115, 'lr': 0.0017659630826499767, 'batch_size': 32, 'hidden_dim': 238, 'weight_decay': 3.2176030007248537e-06, 'dropout': 0.19727111349214355}. Best is trial 39 with value: 5.911322593688965.
# Best hyperparameters: {'hidden_size': 115, 'lr': 0.0017659630826499767, 'batch_size': 32, 'hidden_dim': 238, 'weight_decay': 3.2176030007248537e-06, 'dropout': 0.19727111349214355}

# %%
X_full_train = torch.cat((X_train_final, X_val))
y_full_train = torch.cat((y_train_final, y_val))

val_size_es = int(0.1 * len(X_full_train))
X_train_es, y_train_es = X_full_train[:-val_size_es], y_full_train[:-val_size_es]
X_val_es, y_val_es = X_full_train[-val_size_es:], y_full_train[-val_size_es:]

train_loader = DataLoader(TensorDataset(X_train_es, y_train_es), batch_size=best_params["batch_size"], shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_es, y_val_es), batch_size=best_params["batch_size"], shuffle=False)

# %%
class LiquidNetWithOutput(nn.Module):
    def __init__(self, num_units, output_dim):
        super().__init__()
        self.liquid_net = LiquidNet(num_units=num_units)
        self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Linear(64, output_dim))

    def forward(self, inputs):
        ln_outputs, _ = self.liquid_net(inputs, torch.zeros(inputs.shape[0], self.liquid_net.state_size).to(inputs.device))
        return self.output_layer(ln_outputs)

# %%
model = LiquidNetWithOutput(num_units=best_params["hidden_dim"], output_dim=1)
optimizer = optim.Adam(model.parameters(), lr=best_params["lr"])
criterion = nn.MSELoss()

print("Training full model with early stopping...")
train(model, optimizer, criterion, train_loader, val_loader, epochs=100, patience=10)

model.eval()
with torch.no_grad():
    train_pred = model(X_train)
    test_pred = model(X_test)
# Out:
# Training full model with early stopping...
# Epoch 1/100, Train Loss: 0.0202, Val Loss: 0.0120
# Epoch 2/100, Train Loss: 0.0063, Val Loss: 0.0079
# Epoch 3/100, Train Loss: 0.0044, Val Loss: 0.0064
# Epoch 4/100, Train Loss: 0.0035, Val Loss: 0.0045
# Epoch 5/100, Train Loss: 0.0031, Val Loss: 0.0038
# Epoch 6/100, Train Loss: 0.0029, Val Loss: 0.0038
# Epoch 7/100, Train Loss: 0.0026, Val Loss: 0.0036
# Epoch 8/100, Train Loss: 0.0025, Val Loss: 0.0035
# Epoch 9/100, Train Loss: 0.0026, Val Loss: 0.0038
# Epoch 10/100, Train Loss: 0.0025, Val Loss: 0.0032
# Epoch 11/100, Train Loss: 0.0025, Val Loss: 0.0035
# Epoch 12/100, Train Loss: 0.0024, Val Loss: 0.0032
# Epoch 13/100, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 14/100, Train Loss: 0.0023, Val Loss: 0.0032
# Epoch 15/100, Train Loss: 0.0023, Val Loss: 0.0030
# Epoch 16/100, Train Loss: 0.0021, Val Loss: 0.0031
# Epoch 17/100, Train Loss: 0.0022, Val Loss: 0.0031
# Epoch 18/100, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 19/100, Train Loss: 0.0022, Val Loss: 0.0030
# Epoch 20/100, Train Loss: 0.0021, Val Loss: 0.0032
# Epoch 21/100, Train Loss: 0.0021, Val Loss: 0.0028
# Epoch 22/100, Train Loss: 0.0021, Val Loss: 0.0029
# Epoch 23/100, Train Loss: 0.0021, Val Loss: 0.0032
# Epoch 24/100, Train Loss: 0.0020, Val Loss: 0.0030
# Epoch 25/100, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 26/100, Train Loss: 0.0020, Val Loss: 0.0029
# Epoch 27/100, Train Loss: 0.0022, Val Loss: 0.0028
# Epoch 28/100, Train Loss: 0.0019, Val Loss: 0.0028
# Epoch 29/100, Train Loss: 0.0022, Val Loss: 0.0033
# Epoch 30/100, Train Loss: 0.0019, Val Loss: 0.0028
# Epoch 31/100, Train Loss: 0.0019, Val Loss: 0.0027
# Epoch 32/100, Train Loss: 0.0020, Val Loss: 0.0028
# Epoch 33/100, Train Loss: 0.0020, Val Loss: 0.0026
# Epoch 34/100, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 35/100, Train Loss: 0.0018, Val Loss: 0.0030
# Epoch 36/100, Train Loss: 0.0019, Val Loss: 0.0026
# Epoch 37/100, Train Loss: 0.0018, Val Loss: 0.0029
# Epoch 38/100, Train Loss: 0.0019, Val Loss: 0.0029
# Epoch 39/100, Train Loss: 0.0018, Val Loss: 0.0028
# Epoch 40/100, Train Loss: 0.0017, Val Loss: 0.0028
# Epoch 41/100, Train Loss: 0.0018, Val Loss: 0.0028
# Epoch 42/100, Train Loss: 0.0018, Val Loss: 0.0031
# Epoch 43/100, Train Loss: 0.0018, Val Loss: 0.0027
# Early stopping triggered at epoch 43

# %%
train_pred_inv = scaler.inverse_transform(train_pred.numpy())
y_train_inv = scaler.inverse_transform(y_train.numpy())
train_rmse = math.sqrt(mean_squared_error(y_train_inv, train_pred_inv))
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 4.9713

# %%
pred_path = "predictions/Traffic_LiquidML_train.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, train_pred_inv)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_train_raw.index[-len(train_pred_inv):], y_train_inv, label='Actual')
plt.plot(df_train_raw.index[-len(train_pred_inv):], train_pred_inv, label='LiquidML Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Traffic')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_pred_inv = scaler.inverse_transform(test_pred.numpy())
y_test_inv = scaler.inverse_transform(y_test.numpy())
test_rmse = math.sqrt(mean_squared_error(y_test_inv, test_pred_inv))
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 5.3208

# %%
dataset_name = "Traffic"
rmse_file = "RMSE_LiquidML.json"

try:
    with open(rmse_file, "r") as f:
        rmse_data = json.load(f)
except FileNotFoundError:
    rmse_data = {}

rmse_data[dataset_name] = round(test_rmse, 2)

with open(rmse_file, "w") as f:
    json.dump(rmse_data, f, indent=4)

# %%
pred_path = "predictions/Traffic_LiquidML_test.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, test_pred_inv)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test_raw.index[-len(test_pred_inv):], y_test_inv, label='Actual')
plt.plot(df_test_raw.index[-len(test_pred_inv):], test_pred_inv, label='LiquidML Predicted')
plt.title('Actual vs Predicted Traffic (Test Set)')
plt.xlabel('Date')
plt.ylabel('Traffic')
plt.legend()
plt.show()
