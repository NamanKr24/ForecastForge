# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import shutil
import warnings
import os
import json
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import optuna
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from liquidnet.main import LiquidNet
import random

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
df = pd.read_excel("../datasets/jena_climate.xlsx")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df["Date Time"] = pd.to_datetime(df["Date Time"], dayfirst = True)
df.set_index("Date Time", inplace=True)
df = df[["Tpot (K)"]]
df = df.sort_index()
df = df.iloc[::144]

train_size = int(len(df) * 0.8)
df_train_raw = df.iloc[:train_size]
df_test_raw = df.iloc[train_size:]

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(df_train_raw)
scaled_test = scaler.transform(df_test_raw)

df_train = pd.DataFrame(scaled_train, columns=df.columns, index=df_train_raw.index)
df_test = pd.DataFrame(scaled_test, columns=df.columns, index=df_test_raw.index)

print(f"Training data size: {len(df_train)}")
print(f"Testing data size: {len(df_test)}")
# Out:
# Training data size: 2336
# Testing data size: 585

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i - seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train_np, y_train_np = create_sequences(scaled_train)
X_test_np, y_test_np = create_sequences(scaled_test)

X_train = torch.tensor(X_train_np, dtype=torch.float32)
y_train = torch.tensor(y_train_np, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np, dtype=torch.float32).unsqueeze(1)

val_size = int(0.1 * len(X_train))
X_val, y_val = X_train[-val_size:], y_train[-val_size:]
X_train_final, y_train_final = X_train[:-val_size], y_train[:-val_size]

# %%
def train(model, optimizer, criterion, train_loader, val_loader=None, epochs=50, patience=5):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        train_losses = []
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch) 
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        if val_loader is not None:
            model.eval()
            val_losses = []
            with torch.no_grad():
                for X_val_batch, y_val_batch in val_loader:
                    val_outputs = model(X_val_batch) 
                    val_loss = criterion(val_outputs, y_val_batch)
                    val_losses.append(val_loss.item())
            avg_val_loss = sum(val_losses) / len(val_losses)
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}, Val Loss: {avg_val_loss:.4f}")

            if avg_val_loss < best_loss:
                best_loss = avg_val_loss
                best_model_state = model.state_dict()
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered at epoch {epoch+1}")
                    break
        else:
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}")
            best_model_state = model.state_dict()

    if best_model_state:
        model.load_state_dict(best_model_state)
    return best_loss if val_loader else None

# %%
def objective(trial):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    hidden_size = trial.suggest_int("hidden_size", 32, 128)
    lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128])
    hidden_dim = trial.suggest_int("hidden_dim", 64, 256)

    input_dim = X_train.shape[1]

    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    dropout_rate = trial.suggest_float("dropout", 0.1, 0.5)


    class LiquidNetWithOutput(nn.Module):
        def __init__(self, num_units, output_dim):
            super().__init__()
            self.liquid_net = LiquidNet(num_units=num_units)
            self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Dropout(dropout_rate), nn.Linear(64, output_dim))

        def forward(self, inputs):
            batch_size = inputs.shape[0]
            h0 = torch.zeros(batch_size, self.liquid_net.state_size).to(inputs.device)
            ln_outputs, _ = self.liquid_net(inputs, h0)
            return self.output_layer(ln_outputs)

    model = LiquidNetWithOutput(num_units=hidden_dim, output_dim=1)

    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=False)
    criterion = nn.MSELoss()

    train_dataset = TensorDataset(X_train_final, y_train_final)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    best_val_loss = float("inf")
    patience = 10
    wait = 0

    for epoch in range(50):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = criterion(output, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(X_val).numpy()
            y_val_np = y_val.cpu().numpy()

            val_preds_inv = scaler.inverse_transform(val_preds)
            y_val_inv = scaler.inverse_transform(y_val_np)

            val_rmse = mean_squared_error(y_val_inv, val_preds_inv, squared=False)

        scheduler.step(val_rmse)

        if val_rmse < best_val_loss:
            best_val_loss = val_rmse
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)

best_params = study.best_params
print(f"Best hyperparameters: {best_params}")
# Out:
# [I 2025-05-25 17:33:43,040] A new study created in memory with name: no-name-2a7ae4f7-a233-45ae-8598-d0cd7a836eba
# [I 2025-05-25 17:39:32,541] Trial 0 finished with value: 8.898591995239258 and parameters: {'hidden_size': 50, 'lr': 1.3219142350550203e-05, 'batch_size': 128, 'hidden_dim': 187, 'weight_decay': 1.6464327693135414e-05, 'dropout': 0.2485373255107034}. Best is trial 0 with value: 8.898591995239258.
# [I 2025-05-25 17:40:33,524] Trial 1 finished with value: 3.8928258419036865 and parameters: {'hidden_size': 125, 'lr': 0.0033218693452351142, 'batch_size': 64, 'hidden_dim': 101, 'weight_decay': 0.0043404302618052166, 'dropout': 0.19870151281937978}. Best is trial 1 with value: 3.8928258419036865.
# [I 2025-05-25 17:45:48,206] Trial 2 finished with value: 5.377806663513184 and parameters: {'hidden_size': 67, 'lr': 2.8686988868017093e-05, 'batch_size': 128, 'hidden_dim': 177, 'weight_decay': 0.0030394275977548594, 'dropout': 0.38568849369121416}. Best is trial 1 with value: 3.8928258419036865.
# [I 2025-05-25 17:49:55,956] Trial 3 finished with value: 3.3651106357574463 and parameters: {'hidden_size': 106, 'lr': 0.005938240409115452, 'batch_size': 128, 'hidden_dim': 158, 'weight_decay': 3.6838147646842976e-06, 'dropout': 0.10391323067346124}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 17:55:56,937] Trial 4 finished with value: 3.674086332321167 and parameters: {'hidden_size': 65, 'lr': 0.0011030762089348748, 'batch_size': 128, 'hidden_dim': 191, 'weight_decay': 1.9225147075063833e-06, 'dropout': 0.38006941698011065}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 17:59:59,595] Trial 5 finished with value: 3.4880731105804443 and parameters: {'hidden_size': 49, 'lr': 0.005305661661528122, 'batch_size': 64, 'hidden_dim': 156, 'weight_decay': 5.395408825815575e-06, 'dropout': 0.2289232430669456}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:00:46,566] Trial 6 finished with value: 3.572392225265503 and parameters: {'hidden_size': 112, 'lr': 0.004343414956802097, 'batch_size': 32, 'hidden_dim': 90, 'weight_decay': 0.00021129711834371766, 'dropout': 0.20358352594894513}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:03:15,680] Trial 7 finished with value: 5.209399700164795 and parameters: {'hidden_size': 91, 'lr': 1.736514062193935e-05, 'batch_size': 32, 'hidden_dim': 139, 'weight_decay': 2.2356631271580955e-05, 'dropout': 0.3954460293021177}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:05:10,998] Trial 8 finished with value: 6.121738433837891 and parameters: {'hidden_size': 104, 'lr': 7.706772366099877e-05, 'batch_size': 128, 'hidden_dim': 139, 'weight_decay': 6.513345098030863e-05, 'dropout': 0.2154991829463716}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:06:37,557] Trial 9 finished with value: 3.415886640548706 and parameters: {'hidden_size': 123, 'lr': 0.0007949524434798896, 'batch_size': 32, 'hidden_dim': 112, 'weight_decay': 2.6625323831509388e-05, 'dropout': 0.1766167142155918}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:16:43,258] Trial 10 finished with value: 3.828186273574829 and parameters: {'hidden_size': 87, 'lr': 0.00019891199095647315, 'batch_size': 128, 'hidden_dim': 251, 'weight_decay': 0.00046571674537575637, 'dropout': 0.10576220799039378}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:18:18,067] Trial 11 finished with value: 3.494009494781494 and parameters: {'hidden_size': 128, 'lr': 0.0008892629049951364, 'batch_size': 32, 'hidden_dim': 116, 'weight_decay': 1.798668839790503e-06, 'dropout': 0.10399295514443327}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:18:55,498] Trial 12 finished with value: 3.500213146209717 and parameters: {'hidden_size': 108, 'lr': 0.0010236260362754448, 'batch_size': 32, 'hidden_dim': 65, 'weight_decay': 1.2957564393276856e-05, 'dropout': 0.4933885670350203}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:26:49,204] Trial 13 finished with value: 3.3927719593048096 and parameters: {'hidden_size': 98, 'lr': 0.008885934652866571, 'batch_size': 32, 'hidden_dim': 225, 'weight_decay': 7.484331246646576e-05, 'dropout': 0.1516316601495333}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:35:45,927] Trial 14 finished with value: 3.4108264446258545 and parameters: {'hidden_size': 96, 'lr': 0.008575864630130874, 'batch_size': 64, 'hidden_dim': 226, 'weight_decay': 0.00024116997783615285, 'dropout': 0.1514364247124058}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:41:56,037] Trial 15 finished with value: 3.6158227920532227 and parameters: {'hidden_size': 75, 'lr': 0.002644176259282548, 'batch_size': 128, 'hidden_dim': 223, 'weight_decay': 0.0007113794899297774, 'dropout': 0.27742663695535763}. Best is trial 3 with value: 3.3651106357574463.
# [I 2025-05-25 18:47:30,941] Trial 16 finished with value: 3.352956771850586 and parameters: {'hidden_size': 32, 'lr': 0.008779367387469088, 'batch_size': 32, 'hidden_dim': 215, 'weight_decay': 5.1028648772417934e-06, 'dropout': 0.13482651258918657}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 18:58:40,006] Trial 17 finished with value: 3.5809860229492188 and parameters: {'hidden_size': 39, 'lr': 0.0003384690310247575, 'batch_size': 128, 'hidden_dim': 256, 'weight_decay': 1.0479932904706856e-06, 'dropout': 0.1008118793822611}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:03:46,324] Trial 18 finished with value: 3.3983466625213623 and parameters: {'hidden_size': 32, 'lr': 0.0021807888076559624, 'batch_size': 32, 'hidden_dim': 204, 'weight_decay': 6.311757909503406e-06, 'dropout': 0.3254347201097353}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:08:31,158] Trial 19 finished with value: 3.7711100578308105 and parameters: {'hidden_size': 79, 'lr': 0.00022368656020260367, 'batch_size': 64, 'hidden_dim': 164, 'weight_decay': 4.78797712807127e-06, 'dropout': 0.1476101581981791}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:15:51,959] Trial 20 finished with value: 3.5155234336853027 and parameters: {'hidden_size': 52, 'lr': 0.0019152837509025975, 'batch_size': 128, 'hidden_dim': 206, 'weight_decay': 3.082862117761444e-06, 'dropout': 0.32266872483892434}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:19:55,539] Trial 21 finished with value: 3.4056894779205322 and parameters: {'hidden_size': 101, 'lr': 0.008587729164286111, 'batch_size': 32, 'hidden_dim': 230, 'weight_decay': 5.796060901280141e-05, 'dropout': 0.14179601155034022}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:24:07,894] Trial 22 finished with value: 3.418045997619629 and parameters: {'hidden_size': 116, 'lr': 0.009908291490655448, 'batch_size': 32, 'hidden_dim': 205, 'weight_decay': 7.826392704853246e-06, 'dropout': 0.16812770269069943}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:32:54,026] Trial 23 finished with value: 3.9933793544769287 and parameters: {'hidden_size': 89, 'lr': 0.005854004732942859, 'batch_size': 32, 'hidden_dim': 242, 'weight_decay': 0.009651900329123145, 'dropout': 0.12551747778039124}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:35:54,498] Trial 24 finished with value: 3.3930013179779053 and parameters: {'hidden_size': 96, 'lr': 0.00480682154718119, 'batch_size': 32, 'hidden_dim': 153, 'weight_decay': 4.589069877058342e-05, 'dropout': 0.17694543476163557}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:41:10,746] Trial 25 finished with value: 3.379672050476074 and parameters: {'hidden_size': 116, 'lr': 0.0017695944386774186, 'batch_size': 32, 'hidden_dim': 173, 'weight_decay': 0.00012301225002742252, 'dropout': 0.2654699728207258}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:43:03,682] Trial 26 finished with value: 3.5277817249298096 and parameters: {'hidden_size': 117, 'lr': 0.0015292796519463553, 'batch_size': 32, 'hidden_dim': 138, 'weight_decay': 0.0002004651780358607, 'dropout': 0.27042736762169856}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:48:28,623] Trial 27 finished with value: 3.47896409034729 and parameters: {'hidden_size': 63, 'lr': 0.0005236789921716898, 'batch_size': 32, 'hidden_dim': 175, 'weight_decay': 3.5942938940504234e-05, 'dropout': 0.47244561605742763}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:53:14,038] Trial 28 finished with value: 3.4154207706451416 and parameters: {'hidden_size': 119, 'lr': 0.003607927041446814, 'batch_size': 64, 'hidden_dim': 192, 'weight_decay': 0.0001323194690262052, 'dropout': 0.3418583166272415}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 19:58:57,910] Trial 29 finished with value: 3.5804226398468018 and parameters: {'hidden_size': 111, 'lr': 0.0016396601045424403, 'batch_size': 128, 'hidden_dim': 175, 'weight_decay': 1.0698914723832688e-05, 'dropout': 0.2437471135859266}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:02:07,739] Trial 30 finished with value: 5.073535919189453 and parameters: {'hidden_size': 54, 'lr': 9.49005107423624e-05, 'batch_size': 128, 'hidden_dim': 126, 'weight_decay': 0.0007002431874790898, 'dropout': 0.4300128511445286}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:08:17,300] Trial 31 finished with value: 3.393357753753662 and parameters: {'hidden_size': 105, 'lr': 0.007201262407610201, 'batch_size': 32, 'hidden_dim': 210, 'weight_decay': 1.6751840148275967e-05, 'dropout': 0.1290278166565535}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:17:37,446] Trial 32 finished with value: 3.4087445735931396 and parameters: {'hidden_size': 98, 'lr': 0.0032874852803715555, 'batch_size': 32, 'hidden_dim': 237, 'weight_decay': 0.00010932903461868811, 'dropout': 0.1638968764106846}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:21:17,984] Trial 33 finished with value: 3.629401683807373 and parameters: {'hidden_size': 85, 'lr': 0.00610535693934977, 'batch_size': 32, 'hidden_dim': 220, 'weight_decay': 0.0019726097697007543, 'dropout': 0.19373178611529726}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:25:42,872] Trial 34 finished with value: 3.438687324523926 and parameters: {'hidden_size': 70, 'lr': 0.0031029879583994624, 'batch_size': 32, 'hidden_dim': 189, 'weight_decay': 3.0153305254124197e-06, 'dropout': 0.12626085019374472}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:28:16,776] Trial 35 finished with value: 3.566683292388916 and parameters: {'hidden_size': 122, 'lr': 0.009661860409142714, 'batch_size': 64, 'hidden_dim': 165, 'weight_decay': 0.0004256580787670859, 'dropout': 0.2663357345938162}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:31:05,947] Trial 36 finished with value: 3.6527762413024902 and parameters: {'hidden_size': 110, 'lr': 0.004709564018225575, 'batch_size': 128, 'hidden_dim': 197, 'weight_decay': 1.0084347296466424e-06, 'dropout': 0.22663024979478302}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:36:03,567] Trial 37 finished with value: 3.410828113555908 and parameters: {'hidden_size': 93, 'lr': 0.0014206748707966366, 'batch_size': 32, 'hidden_dim': 179, 'weight_decay': 3.573197248075212e-06, 'dropout': 0.19922328780658952}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:39:01,356] Trial 38 finished with value: 3.411768674850464 and parameters: {'hidden_size': 83, 'lr': 0.005706229458679787, 'batch_size': 32, 'hidden_dim': 148, 'weight_decay': 7.757124238630658e-05, 'dropout': 0.2976073890717208}. Best is trial 16 with value: 3.352956771850586.
# [I 2025-05-25 20:46:25,048] Trial 39 finished with value: 3.791583299636841 and parameters: {'hidden_size': 101, 'lr': 0.0023415069887681573, 'batch_size': 128, 'hidden_dim': 213, 'weight_decay': 0.0017835163719398057, 'dropout': 0.36516327321717845}. Best is trial 16 with value: 3.352956771850586.
# Best hyperparameters: {'hidden_size': 32, 'lr': 0.008779367387469088, 'batch_size': 32, 'hidden_dim': 215, 'weight_decay': 5.1028648772417934e-06, 'dropout': 0.13482651258918657}

# %%
X_full_train = torch.cat((X_train_final, X_val))
y_full_train = torch.cat((y_train_final, y_val))

val_size_es = int(0.1 * len(X_full_train))
X_train_es, y_train_es = X_full_train[:-val_size_es], y_full_train[:-val_size_es]
X_val_es, y_val_es = X_full_train[-val_size_es:], y_full_train[-val_size_es:]

train_loader = DataLoader(TensorDataset(X_train_es, y_train_es), batch_size=best_params["batch_size"], shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_es, y_val_es), batch_size=best_params["batch_size"], shuffle=False)

# %%
class LiquidNetWithOutput(nn.Module):
    def __init__(self, num_units, output_dim):
        super().__init__()
        self.liquid_net = LiquidNet(num_units=num_units)
        self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Linear(64, output_dim))

    def forward(self, inputs):
        ln_outputs, _ = self.liquid_net(inputs, torch.zeros(inputs.shape[0], self.liquid_net.state_size).to(inputs.device))
        return self.output_layer(ln_outputs)

# %%
model = LiquidNetWithOutput(num_units=best_params["hidden_dim"], output_dim=1)
optimizer = optim.Adam(model.parameters(), lr=best_params["lr"])
criterion = nn.MSELoss()

print("Training full model with early stopping...")
train(model, optimizer, criterion, train_loader, val_loader, epochs=100, patience=10)

model.eval()
with torch.no_grad():
    train_pred = model(X_train)
    test_pred = model(X_test)
# Out:
# Training full model with early stopping...
# Epoch 1/100, Train Loss: 0.0179, Val Loss: 0.0049
# Epoch 2/100, Train Loss: 0.0054, Val Loss: 0.0039
# Epoch 3/100, Train Loss: 0.0046, Val Loss: 0.0082
# Epoch 4/100, Train Loss: 0.0047, Val Loss: 0.0048
# Epoch 5/100, Train Loss: 0.0048, Val Loss: 0.0079
# Epoch 6/100, Train Loss: 0.0042, Val Loss: 0.0068
# Epoch 7/100, Train Loss: 0.0045, Val Loss: 0.0040
# Epoch 8/100, Train Loss: 0.0046, Val Loss: 0.0119
# Epoch 9/100, Train Loss: 0.0054, Val Loss: 0.0046
# Epoch 10/100, Train Loss: 0.0041, Val Loss: 0.0054
# Epoch 11/100, Train Loss: 0.0043, Val Loss: 0.0075
# Epoch 12/100, Train Loss: 0.0051, Val Loss: 0.0035
# Epoch 13/100, Train Loss: 0.0043, Val Loss: 0.0040
# Epoch 14/100, Train Loss: 0.0041, Val Loss: 0.0034
# Epoch 15/100, Train Loss: 0.0043, Val Loss: 0.0047
# Epoch 16/100, Train Loss: 0.0043, Val Loss: 0.0042
# Epoch 17/100, Train Loss: 0.0044, Val Loss: 0.0057
# Epoch 18/100, Train Loss: 0.0042, Val Loss: 0.0041
# Epoch 19/100, Train Loss: 0.0041, Val Loss: 0.0039
# Epoch 20/100, Train Loss: 0.0050, Val Loss: 0.0111
# Epoch 21/100, Train Loss: 0.0057, Val Loss: 0.0037
# Epoch 22/100, Train Loss: 0.0040, Val Loss: 0.0036
# Epoch 23/100, Train Loss: 0.0041, Val Loss: 0.0063
# Epoch 24/100, Train Loss: 0.0041, Val Loss: 0.0035
# Early stopping triggered at epoch 24

# %%
train_pred_inv = scaler.inverse_transform(train_pred.numpy())
y_train_inv = scaler.inverse_transform(y_train.numpy())
train_rmse = math.sqrt(mean_squared_error(y_train_inv, train_pred_inv))
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 3.3134

# %%
pred_path = "predictions/Weather_LiquidML_train.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, train_pred_inv)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_train_raw.index[-len(train_pred_inv):], y_train_inv, label='Actual')
plt.plot(df_train_raw.index[-len(train_pred_inv):], train_pred_inv, label='LiquidML Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_pred_inv = scaler.inverse_transform(test_pred.numpy())
y_test_inv = scaler.inverse_transform(y_test.numpy())
test_rmse = math.sqrt(mean_squared_error(y_test_inv, test_pred_inv))
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 3.5364

# %%
dataset_name = "Weather"
rmse_file = "RMSE_LiquidML.json"

try:
    with open(rmse_file, "r") as f:
        rmse_data = json.load(f)
except FileNotFoundError:
    rmse_data = {}

rmse_data[dataset_name] = round(test_rmse, 2)

with open(rmse_file, "w") as f:
    json.dump(rmse_data, f, indent=4)

# %%
pred_path = "predictions/Weather_LiquidML_test.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, test_pred_inv)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test_raw.index[-len(test_pred_inv):], y_test_inv, label='Actual')
plt.plot(df_test_raw.index[-len(test_pred_inv):], test_pred_inv, label='LiquidML Predicted')
plt.title('Actual vs Predicted Temperature (Test Set)')
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.legend()
plt.show()
