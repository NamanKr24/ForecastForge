# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import shutil
import warnings
import os
import json
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import optuna
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from liquidnet.main import LiquidNet
import random

# %%
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %%
df = pd.read_excel("../datasets/AEP_hourly_processed.xlsx")
df = df.drop(columns=["Unnamed: 0"], errors="ignore")
df["Datetime"] = pd.to_datetime(df["Datetime"])
df = df.sort_values("Datetime")
df.set_index("Datetime", inplace=True)
df = df[["AEP_MW"]]
df = df.iloc[:5000]

train_size = int(len(df) * 0.8)
df_train_raw = df.iloc[:train_size]
df_test_raw = df.iloc[train_size:]

scaler = MinMaxScaler()
scaled_train = scaler.fit_transform(df_train_raw)
scaled_test = scaler.transform(df_test_raw)

df_train = pd.DataFrame(scaled_train, columns=df.columns, index=df_train_raw.index)
df_test = pd.DataFrame(scaled_test, columns=df.columns, index=df_test_raw.index)

print(f"Training data size: {len(df_train)}")
print(f"Testing data size: {len(df_test)}")
# Out:
# Training data size: 4000
# Testing data size: 1000

# %%
def create_sequences(data, seq_length=60):
    X, y = [], []
    for i in range(seq_length, len(data)):
        X.append(data[i - seq_length:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train_np, y_train_np = create_sequences(scaled_train)
X_test_np, y_test_np = create_sequences(scaled_test)

X_train = torch.tensor(X_train_np, dtype=torch.float32)
y_train = torch.tensor(y_train_np, dtype=torch.float32).unsqueeze(1)
X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np, dtype=torch.float32).unsqueeze(1)

val_size = int(0.1 * len(X_train))
X_val, y_val = X_train[-val_size:], y_train[-val_size:]
X_train_final, y_train_final = X_train[:-val_size], y_train[:-val_size]

# %%
def train(model, optimizer, criterion, train_loader, val_loader=None, epochs=50, patience=5):
    best_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        train_losses = []
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs = model(X_batch) 
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()
            train_losses.append(loss.item())

        if val_loader is not None:
            model.eval()
            val_losses = []
            with torch.no_grad():
                for X_val_batch, y_val_batch in val_loader:
                    val_outputs = model(X_val_batch) 
                    val_loss = criterion(val_outputs, y_val_batch)
                    val_losses.append(val_loss.item())
            avg_val_loss = sum(val_losses) / len(val_losses)
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}, Val Loss: {avg_val_loss:.4f}")

            if avg_val_loss < best_loss:
                best_loss = avg_val_loss
                best_model_state = model.state_dict()
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered at epoch {epoch+1}")
                    break
        else:
            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {np.mean(train_losses):.4f}")
            best_model_state = model.state_dict()

    if best_model_state:
        model.load_state_dict(best_model_state)
    return best_loss if val_loader else None

# %%
def objective(trial):
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    hidden_size = trial.suggest_int("hidden_size", 32, 128)
    lr = trial.suggest_float("lr", 1e-5, 1e-2, log=True)
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 128])
    hidden_dim = trial.suggest_int("hidden_dim", 64, 256)

    input_dim = X_train.shape[1]

    weight_decay = trial.suggest_float("weight_decay", 1e-6, 1e-2, log=True)
    dropout_rate = trial.suggest_float("dropout", 0.1, 0.5)


    class LiquidNetWithOutput(nn.Module):
        def __init__(self, num_units, output_dim):
            super().__init__()
            self.liquid_net = LiquidNet(num_units=num_units)
            self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Dropout(dropout_rate), nn.Linear(64, output_dim))

        def forward(self, inputs):
            batch_size = inputs.shape[0]
            h0 = torch.zeros(batch_size, self.liquid_net.state_size).to(inputs.device)
            ln_outputs, _ = self.liquid_net(inputs, h0)
            return self.output_layer(ln_outputs)

    model = LiquidNetWithOutput(num_units=hidden_dim, output_dim=1)

    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3, verbose=False)
    criterion = nn.MSELoss()

    train_dataset = TensorDataset(X_train_final, y_train_final)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    best_val_loss = float("inf")
    patience = 10
    wait = 0

    for epoch in range(50):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = criterion(output, y_batch)
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_preds = model(X_val).numpy()
            y_val_np = y_val.cpu().numpy()

            val_preds_inv = scaler.inverse_transform(val_preds)
            y_val_inv = scaler.inverse_transform(y_val_np)

            val_rmse = mean_squared_error(y_val_inv, val_preds_inv, squared=False)

        scheduler.step(val_rmse)

        if val_rmse < best_val_loss:
            best_val_loss = val_rmse
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                break

    return best_val_loss

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=40)

best_params = study.best_params
print(f"Best hyperparameters: {best_params}")
# Out:
# [I 2025-05-25 21:10:20,217] A new study created in memory with name: no-name-d0b30426-9c6c-490c-a7b2-c12af1d04c7d
# [I 2025-05-25 21:11:16,814] Trial 0 finished with value: 1477.767333984375 and parameters: {'hidden_size': 97, 'lr': 2.112481221602436e-05, 'batch_size': 32, 'hidden_dim': 107, 'weight_decay': 5.587772000603893e-06, 'dropout': 0.4958719327393595}. Best is trial 0 with value: 1477.767333984375.
# [I 2025-05-25 21:11:38,258] Trial 1 finished with value: 1383.2825927734375 and parameters: {'hidden_size': 40, 'lr': 2.2994967066524767e-05, 'batch_size': 32, 'hidden_dim': 70, 'weight_decay': 0.00011885960816946636, 'dropout': 0.11276957601113745}. Best is trial 1 with value: 1383.2825927734375.
# [I 2025-05-25 21:13:04,963] Trial 2 finished with value: 564.8922119140625 and parameters: {'hidden_size': 94, 'lr': 0.00026923805844360926, 'batch_size': 64, 'hidden_dim': 83, 'weight_decay': 0.0004996020107788977, 'dropout': 0.4716255682450048}. Best is trial 2 with value: 564.8922119140625.
# [I 2025-05-25 21:13:56,294] Trial 3 finished with value: 1393.6322021484375 and parameters: {'hidden_size': 69, 'lr': 1.3464871562583313e-05, 'batch_size': 64, 'hidden_dim': 100, 'weight_decay': 0.00048581687920747156, 'dropout': 0.17414489383105236}. Best is trial 2 with value: 564.8922119140625.
# [I 2025-05-25 21:14:59,588] Trial 4 finished with value: 1413.7332763671875 and parameters: {'hidden_size': 82, 'lr': 3.116896429659434e-05, 'batch_size': 64, 'hidden_dim': 114, 'weight_decay': 0.00019494192696918367, 'dropout': 0.42141982029281155}. Best is trial 2 with value: 564.8922119140625.
# [I 2025-05-25 21:18:34,641] Trial 5 finished with value: 740.6848754882812 and parameters: {'hidden_size': 119, 'lr': 0.002103323788787007, 'batch_size': 64, 'hidden_dim': 127, 'weight_decay': 0.005761107032230817, 'dropout': 0.38942159391392595}. Best is trial 2 with value: 564.8922119140625.
# [I 2025-05-25 21:19:40,408] Trial 6 finished with value: 367.973876953125 and parameters: {'hidden_size': 72, 'lr': 0.0053646378253026, 'batch_size': 64, 'hidden_dim': 88, 'weight_decay': 3.4107954485145476e-06, 'dropout': 0.3211508302548328}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 21:21:06,588] Trial 7 finished with value: 530.9711303710938 and parameters: {'hidden_size': 65, 'lr': 0.00021362570148057548, 'batch_size': 32, 'hidden_dim': 99, 'weight_decay': 0.00010416245996806361, 'dropout': 0.14842409524475336}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 21:24:11,250] Trial 8 finished with value: 637.337158203125 and parameters: {'hidden_size': 63, 'lr': 0.0003407431039039843, 'batch_size': 64, 'hidden_dim': 113, 'weight_decay': 0.0020026197029370087, 'dropout': 0.41616932781465454}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 21:28:03,334] Trial 9 finished with value: 640.052001953125 and parameters: {'hidden_size': 88, 'lr': 0.00011300312265110682, 'batch_size': 64, 'hidden_dim': 122, 'weight_decay': 0.0001793283905732008, 'dropout': 0.32256499121085325}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 21:43:57,708] Trial 10 finished with value: 421.052490234375 and parameters: {'hidden_size': 32, 'lr': 0.00938391138315365, 'batch_size': 128, 'hidden_dim': 235, 'weight_decay': 1.669250193748515e-06, 'dropout': 0.24585855537367396}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:01:32,453] Trial 11 finished with value: 463.87628173828125 and parameters: {'hidden_size': 32, 'lr': 0.009069303929865033, 'batch_size': 128, 'hidden_dim': 243, 'weight_decay': 1.0617589459059578e-06, 'dropout': 0.2482901083414319}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:14:25,707] Trial 12 finished with value: 380.23114013671875 and parameters: {'hidden_size': 48, 'lr': 0.008133973094052232, 'batch_size': 128, 'hidden_dim': 207, 'weight_decay': 1.2437586752243177e-05, 'dropout': 0.26071364859106305}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:23:09,420] Trial 13 finished with value: 496.6978454589844 and parameters: {'hidden_size': 50, 'lr': 0.002003699441224149, 'batch_size': 128, 'hidden_dim': 193, 'weight_decay': 1.4784322695805044e-05, 'dropout': 0.31669545345859107}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:32:19,025] Trial 14 finished with value: 461.61053466796875 and parameters: {'hidden_size': 54, 'lr': 0.0024380816521030304, 'batch_size': 128, 'hidden_dim': 177, 'weight_decay': 2.004417167367344e-05, 'dropout': 0.258012455365753}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:44:41,812] Trial 15 finished with value: 485.74310302734375 and parameters: {'hidden_size': 109, 'lr': 0.004264254894875046, 'batch_size': 128, 'hidden_dim': 205, 'weight_decay': 2.0748183920442324e-05, 'dropout': 0.3544448682216023}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 22:51:09,836] Trial 16 finished with value: 635.185791015625 and parameters: {'hidden_size': 75, 'lr': 0.0005742956815356522, 'batch_size': 128, 'hidden_dim': 167, 'weight_decay': 4.362324492975407e-06, 'dropout': 0.2043361184431079}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:04:41,477] Trial 17 finished with value: 388.9500732421875 and parameters: {'hidden_size': 51, 'lr': 0.0007821626151240693, 'batch_size': 64, 'hidden_dim': 218, 'weight_decay': 5.5578584182167866e-06, 'dropout': 0.286416425960773}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:11:06,339] Trial 18 finished with value: 419.4152526855469 and parameters: {'hidden_size': 60, 'lr': 0.003821113494401689, 'batch_size': 128, 'hidden_dim': 145, 'weight_decay': 4.334464829460203e-05, 'dropout': 0.20647011619763292}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:13:17,321] Trial 19 finished with value: 556.5096435546875 and parameters: {'hidden_size': 44, 'lr': 0.0010246693640927305, 'batch_size': 32, 'hidden_dim': 146, 'weight_decay': 3.0770071794368317e-06, 'dropout': 0.3586622940737977}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:24:01,459] Trial 20 finished with value: 369.4017639160156 and parameters: {'hidden_size': 77, 'lr': 0.0051780498762829434, 'batch_size': 128, 'hidden_dim': 189, 'weight_decay': 1.1198040884633942e-05, 'dropout': 0.2843515310151599}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:34:19,862] Trial 21 finished with value: 488.2072448730469 and parameters: {'hidden_size': 76, 'lr': 0.005581056870105157, 'batch_size': 128, 'hidden_dim': 190, 'weight_decay': 1.0688667659923157e-05, 'dropout': 0.2903825839971976}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:46:02,923] Trial 22 finished with value: 467.39337158203125 and parameters: {'hidden_size': 83, 'lr': 0.005748589140974132, 'batch_size': 128, 'hidden_dim': 230, 'weight_decay': 2.9377026313110335e-05, 'dropout': 0.33762272761653245}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-25 23:57:06,880] Trial 23 finished with value: 504.3783874511719 and parameters: {'hidden_size': 101, 'lr': 0.0012079103810270293, 'batch_size': 128, 'hidden_dim': 206, 'weight_decay': 5.348137654946258e-05, 'dropout': 0.27149195388025116}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-26 00:04:15,708] Trial 24 finished with value: 402.91583251953125 and parameters: {'hidden_size': 71, 'lr': 0.0030697892117486367, 'batch_size': 128, 'hidden_dim': 157, 'weight_decay': 2.2327987586748248e-06, 'dropout': 0.22075844628281216}. Best is trial 6 with value: 367.973876953125.
# [I 2025-05-26 00:12:55,289] Trial 25 finished with value: 342.41644287109375 and parameters: {'hidden_size': 88, 'lr': 0.007611119514790381, 'batch_size': 64, 'hidden_dim': 174, 'weight_decay': 7.105004089675125e-06, 'dropout': 0.30262736416834257}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 00:31:40,942] Trial 26 finished with value: 417.7540283203125 and parameters: {'hidden_size': 108, 'lr': 0.0017163293578275841, 'batch_size': 64, 'hidden_dim': 254, 'weight_decay': 7.714274277972783e-06, 'dropout': 0.30242644817270503}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 00:40:38,208] Trial 27 finished with value: 499.0561828613281 and parameters: {'hidden_size': 87, 'lr': 0.005009780033501624, 'batch_size': 64, 'hidden_dim': 177, 'weight_decay': 1.3787680150503938e-06, 'dropout': 0.37543614129883823}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 00:42:04,404] Trial 28 finished with value: 1479.7371826171875 and parameters: {'hidden_size': 90, 'lr': 9.950740000992141e-05, 'batch_size': 64, 'hidden_dim': 141, 'weight_decay': 3.2512506500274392e-06, 'dropout': 0.33759191364111185}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 00:43:11,206] Trial 29 finished with value: 469.4415588378906 and parameters: {'hidden_size': 100, 'lr': 0.0005997718906875982, 'batch_size': 32, 'hidden_dim': 64, 'weight_decay': 6.6707501052909926e-06, 'dropout': 0.41653904659790164}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 00:50:25,573] Trial 30 finished with value: 390.7366027832031 and parameters: {'hidden_size': 123, 'lr': 0.0033069463546133854, 'batch_size': 64, 'hidden_dim': 160, 'weight_decay': 4.8745884500680904e-05, 'dropout': 0.3096481918999463}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:00:45,415] Trial 31 finished with value: 374.6087341308594 and parameters: {'hidden_size': 76, 'lr': 0.009997142548154214, 'batch_size': 64, 'hidden_dim': 190, 'weight_decay': 8.746834531274003e-06, 'dropout': 0.2343544353951952}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:11:12,793] Trial 32 finished with value: 349.45062255859375 and parameters: {'hidden_size': 77, 'lr': 0.006980357591523559, 'batch_size': 64, 'hidden_dim': 191, 'weight_decay': 8.295940785589627e-06, 'dropout': 0.23475482617888652}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:20:04,012] Trial 33 finished with value: 393.5933837890625 and parameters: {'hidden_size': 94, 'lr': 0.006151284916377756, 'batch_size': 64, 'hidden_dim': 176, 'weight_decay': 2.7897012729314793e-06, 'dropout': 0.17829149973109598}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:21:12,111] Trial 34 finished with value: 530.611328125 and parameters: {'hidden_size': 57, 'lr': 0.001480054184125719, 'batch_size': 64, 'hidden_dim': 81, 'weight_decay': 4.402105753628583e-06, 'dropout': 0.2738180738467381}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:35:10,790] Trial 35 finished with value: 438.6165466308594 and parameters: {'hidden_size': 83, 'lr': 0.002831733517917891, 'batch_size': 64, 'hidden_dim': 222, 'weight_decay': 2.036657799012358e-06, 'dropout': 0.46633847071632073}. Best is trial 25 with value: 342.41644287109375.
# [I 2025-05-26 01:45:50,538] Trial 36 finished with value: 342.23785400390625 and parameters: {'hidden_size': 69, 'lr': 0.006358833464819626, 'batch_size': 32, 'hidden_dim': 197, 'weight_decay': 2.5833510043602363e-05, 'dropout': 0.17245036306634937}. Best is trial 36 with value: 342.23785400390625.
# [I 2025-05-26 01:51:41,325] Trial 37 finished with value: 333.78521728515625 and parameters: {'hidden_size': 69, 'lr': 0.0067907111503686625, 'batch_size': 32, 'hidden_dim': 170, 'weight_decay': 2.8224791021117324e-05, 'dropout': 0.10889907348008199}. Best is trial 37 with value: 333.78521728515625.
# [I 2025-05-26 01:59:10,860] Trial 38 finished with value: 443.4545593261719 and parameters: {'hidden_size': 66, 'lr': 0.007052263950498135, 'batch_size': 32, 'hidden_dim': 170, 'weight_decay': 0.00043042785847943575, 'dropout': 0.11079079208660365}. Best is trial 37 with value: 333.78521728515625.
# [I 2025-05-26 02:10:16,414] Trial 39 finished with value: 523.0958862304688 and parameters: {'hidden_size': 67, 'lr': 5.839800823547766e-05, 'batch_size': 32, 'hidden_dim': 201, 'weight_decay': 8.618232773929811e-05, 'dropout': 0.14466082203191644}. Best is trial 37 with value: 333.78521728515625.
# Best hyperparameters: {'hidden_size': 69, 'lr': 0.0067907111503686625, 'batch_size': 32, 'hidden_dim': 170, 'weight_decay': 2.8224791021117324e-05, 'dropout': 0.10889907348008199}

# %%
X_full_train = torch.cat((X_train_final, X_val))
y_full_train = torch.cat((y_train_final, y_val))

val_size_es = int(0.1 * len(X_full_train))
X_train_es, y_train_es = X_full_train[:-val_size_es], y_full_train[:-val_size_es]
X_val_es, y_val_es = X_full_train[-val_size_es:], y_full_train[-val_size_es:]

train_loader = DataLoader(TensorDataset(X_train_es, y_train_es), batch_size=best_params["batch_size"], shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_es, y_val_es), batch_size=best_params["batch_size"], shuffle=False)

# %%
class LiquidNetWithOutput(nn.Module):
    def __init__(self, num_units, output_dim):
        super().__init__()
        self.liquid_net = LiquidNet(num_units=num_units)
        self.output_layer = nn.Sequential(nn.Linear(num_units, 64), nn.ReLU(), nn.Linear(64, output_dim))

    def forward(self, inputs):
        ln_outputs, _ = self.liquid_net(inputs, torch.zeros(inputs.shape[0], self.liquid_net.state_size).to(inputs.device))
        return self.output_layer(ln_outputs)

# %%
model = LiquidNetWithOutput(num_units=best_params["hidden_dim"], output_dim=1)
optimizer = optim.Adam(model.parameters(), lr=best_params["lr"])
criterion = nn.MSELoss()

print("Training full model with early stopping...")
train(model, optimizer, criterion, train_loader, val_loader, epochs=100, patience=10)

model.eval()
with torch.no_grad():
    train_pred = model(X_train)
    test_pred = model(X_test)
# Out:
# Training full model with early stopping...
# Epoch 1/100, Train Loss: 0.0151, Val Loss: 0.0040
# Epoch 2/100, Train Loss: 0.0024, Val Loss: 0.0016
# Epoch 3/100, Train Loss: 0.0015, Val Loss: 0.0014
# Epoch 4/100, Train Loss: 0.0014, Val Loss: 0.0019
# Epoch 5/100, Train Loss: 0.0011, Val Loss: 0.0020
# Epoch 6/100, Train Loss: 0.0011, Val Loss: 0.0013
# Epoch 7/100, Train Loss: 0.0010, Val Loss: 0.0014
# Epoch 8/100, Train Loss: 0.0009, Val Loss: 0.0013
# Epoch 9/100, Train Loss: 0.0008, Val Loss: 0.0014
# Epoch 10/100, Train Loss: 0.0008, Val Loss: 0.0010
# Epoch 11/100, Train Loss: 0.0008, Val Loss: 0.0011
# Epoch 12/100, Train Loss: 0.0011, Val Loss: 0.0011
# Epoch 13/100, Train Loss: 0.0009, Val Loss: 0.0008
# Epoch 14/100, Train Loss: 0.0008, Val Loss: 0.0010
# Epoch 15/100, Train Loss: 0.0006, Val Loss: 0.0010
# Epoch 16/100, Train Loss: 0.0007, Val Loss: 0.0009
# Epoch 17/100, Train Loss: 0.0006, Val Loss: 0.0011
# Epoch 18/100, Train Loss: 0.0006, Val Loss: 0.0011
# Epoch 19/100, Train Loss: 0.0006, Val Loss: 0.0008
# Epoch 20/100, Train Loss: 0.0005, Val Loss: 0.0007
# Epoch 21/100, Train Loss: 0.0006, Val Loss: 0.0007
# Epoch 22/100, Train Loss: 0.0005, Val Loss: 0.0010
# Epoch 23/100, Train Loss: 0.0005, Val Loss: 0.0007
# Epoch 24/100, Train Loss: 0.0006, Val Loss: 0.0010
# Epoch 25/100, Train Loss: 0.0005, Val Loss: 0.0010
# Epoch 26/100, Train Loss: 0.0006, Val Loss: 0.0006
# Epoch 27/100, Train Loss: 0.0004, Val Loss: 0.0008
# Epoch 28/100, Train Loss: 0.0004, Val Loss: 0.0007
# Epoch 29/100, Train Loss: 0.0004, Val Loss: 0.0007
# Epoch 30/100, Train Loss: 0.0004, Val Loss: 0.0006
# Epoch 31/100, Train Loss: 0.0004, Val Loss: 0.0007
# Epoch 32/100, Train Loss: 0.0006, Val Loss: 0.0015
# Epoch 33/100, Train Loss: 0.0005, Val Loss: 0.0009
# Epoch 34/100, Train Loss: 0.0004, Val Loss: 0.0006
# Epoch 35/100, Train Loss: 0.0004, Val Loss: 0.0007
# Epoch 36/100, Train Loss: 0.0005, Val Loss: 0.0009
# Epoch 37/100, Train Loss: 0.0004, Val Loss: 0.0006
# Epoch 38/100, Train Loss: 0.0004, Val Loss: 0.0012
# Epoch 39/100, Train Loss: 0.0004, Val Loss: 0.0006
# Epoch 40/100, Train Loss: 0.0004, Val Loss: 0.0006
# Early stopping triggered at epoch 40

# %%
train_pred_inv = scaler.inverse_transform(train_pred.numpy())
y_train_inv = scaler.inverse_transform(y_train.numpy())
train_rmse = math.sqrt(mean_squared_error(y_train_inv, train_pred_inv))
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 246.0775

# %%
pred_path = "predictions/Energy_LiquidML_train.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, train_pred_inv)

# %%
plt.figure(figsize=(12, 5))
plt.plot(df_train_raw.index[-len(train_pred_inv):], y_train_inv, label='Actual')
plt.plot(df_train_raw.index[-len(train_pred_inv):], train_pred_inv, label='LiquidML Predicted')
plt.title('Training Data: Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Energy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
test_pred_inv = scaler.inverse_transform(test_pred.numpy())
y_test_inv = scaler.inverse_transform(y_test.numpy())
test_rmse = math.sqrt(mean_squared_error(y_test_inv, test_pred_inv))
print(f"Test RMSE: {test_rmse:.4f}")
# Out:
# Test RMSE: 430.7363

# %%
dataset_name = "Energy"
rmse_file = "RMSE_LiquidML.json"

try:
    with open(rmse_file, "r") as f:
        rmse_data = json.load(f)
except FileNotFoundError:
    rmse_data = {}

rmse_data[dataset_name] = round(test_rmse, 2)

with open(rmse_file, "w") as f:
    json.dump(rmse_data, f, indent=4)

# %%
pred_path = "predictions/Energy_LiquidML_test.npy"
os.makedirs("predictions", exist_ok=True)
np.save(pred_path, test_pred_inv)

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test_raw.index[-len(test_pred_inv):], y_test_inv, label='Actual')
plt.plot(df_test_raw.index[-len(test_pred_inv):], test_pred_inv, label='LiquidML Predicted')
plt.title('Actual vs Predicted Energy Consumed (Test Set)')
plt.xlabel('Date')
plt.ylabel('Energy')
plt.legend()
plt.show()
